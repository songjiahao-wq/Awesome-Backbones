# %% [markdown]
# <a href="https://colab.research.google.com/github/songjiahao-wq/Awesome-Backbones/blob/main/LINEA_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/SebastianJanampa/LINEA.git
# %cd LINEA
# !pip install -r requirements.txt
# %cd ..
# %cp LINEA/examples/example1.jpg example1.jpg
# Out:
# Cloning into 'LINEA'...
# remote: Enumerating objects: 250, done.
# remote: Counting objects: 100% (250/250), done.
# remote: Compressing objects: 100% (135/135), done.
# remote: Total 250 (delta 119), reused 232 (delta 108), pack-reused 0 (from 0)
# Receiving objects: 100% (250/250), 3.05 MiB | 32.48 MiB/s, done.
# Resolving deltas: 100% (119/119), done.
# /content/LINEA
# Requirement already satisfied: torch>=2.0.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.9.0+cu126)
# Requirement already satisfied: torchvision>=0.15.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (0.24.0+cu126)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (1.16.3)
# Collecting calflops (from -r requirements.txt (line 4))
#   Downloading calflops-0.3.2-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (4.57.3)
# Collecting tensorboardx (from -r requirements.txt (line 6))
#   Downloading tensorboardx-2.6.4-py3-none-any.whl.metadata (6.2 kB)
# Collecting addict (from -r requirements.txt (line 7))
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Collecting yapf (from -r requirements.txt (line 8))
#   Downloading yapf-0.43.0-py3-none-any.whl.metadata (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (2.0.11)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (3.20.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.1->-r requirements.txt (line 1)) (3.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision>=0.15.2->-r requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision>=0.15.2->-r requirements.txt (line 2)) (11.3.0)
# Requirement already satisfied: accelerate>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from calflops->-r requirements.txt (line 4)) (1.12.0)
# Requirement already satisfied: huggingface-hub>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from calflops->-r requirements.txt (line 4)) (0.36.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 5)) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 5)) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 5)) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 5)) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 5)) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 5)) (4.67.1)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.12/dist-packages (from tensorboardx->-r requirements.txt (line 6)) (5.29.5)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.12/dist-packages (from yapf->-r requirements.txt (line 8)) (4.5.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.22.0->calflops->-r requirements.txt (line 4)) (5.9.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.16.4->calflops->-r requirements.txt (line 4)) (1.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.1->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.1->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->-r requirements.txt (line 5)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->-r requirements.txt (line 5)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->-r requirements.txt (line 5)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->-r requirements.txt (line 5)) (2026.1.4)
# Downloading calflops-0.3.2-py3-none-any.whl (29 kB)
# Downloading tensorboardx-2.6.4-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 9.8 MB/s eta 0:00:00
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading yapf-0.43.0-py3-none-any.whl (256 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 28.2 MB/s eta 0:00:00
# Installing collected packages: addict, yapf, tensorboardx, calflops
# Successfully installed addict-2.4.0 calflops-0.3.2 tensorboardx-2.6.4 yapf-0.43.0
# /content

# %%
from LINEA.models.linea.hgnetv2 import build_hgnetv2
from LINEA.models.linea.hybrid_encoder import build_hybrid_encoder
from LINEA.models.linea.decoder import build_decoder
from LINEA.models.linea.linea import LINEA, PostProcess

def build_model(args):
  backbone = build_hgnetv2(args)
  encoder = build_hybrid_encoder(args)
  decoder = build_decoder(args)
  model = LINEA(backbone, encoder, decoder)
  post_process = PostProcess()
  return model, post_process
# Out:
# /content/LINEA/models/linea/attention_mechanism.py:113: SyntaxWarning: invalid escape sequence '\s'
#   :param input_flatten               (N, \sum_{l=0}^{L-1} H_l \cdot W_l, C)
# /content/LINEA/models/linea/attention_mechanism.py:191: SyntaxWarning: invalid escape sequence '\s'
#   :param value               (N, \sum_{l=0}^{L-1} H_l \cdot W_l, C)

# %%
LINEA_MODELS = {
    'n': './LINEA/configs/linea/linea_hgnetv2_n.py',
    's': './LINEA/configs/linea/linea_hgnetv2_s.py',
    'm': './LINEA/configs/linea/linea_hgnetv2_m.py',
    'l': './LINEA/configs/linea/linea_hgnetv2_l.py'
}

model_size = 'l'

# %%
from LINEA.util.slconfig import DictAction, SLConfig

cfg = SLConfig.fromfile(LINEA_MODELS[model_size])
cfg.pretrained = False

# %%
import torch
from torch import nn

weigths_folder = './weights'
download_url = f"https://github.com/SebastianJanampa/storage/releases/download/LINEA/linea_hgnetv2_{model_size}.pth"
state = torch.hub.load_state_dict_from_url(download_url, map_location='cpu', model_dir=weigths_folder)
# Out:
# Downloading: "https://github.com/SebastianJanampa/storage/releases/download/LINEA/linea_hgnetv2_l.pth" to ./weights/linea_hgnetv2_l.pth
# 100%|██████████| 99.2M/99.2M [00:07<00:00, 13.3MB/s]

# %%
model, postprocessor = build_model(cfg)
checkpoint = torch.load(f"{weigths_folder}/linea_hgnetv2_{model_size}.pth", map_location='cpu')
model.load_state_dict(checkpoint['model'], strict=True)

class Model(nn.Module):
  def __init__(self):
    super().__init__()
    self.model = model.deploy()
    self.postprocessor = postprocessor.deploy()

  def forward(self, images, orig_target_sizes):
    outputs = self.model(images)
    outputs = self.postprocessor(outputs, orig_target_sizes)
    return outputs

model = Model()

# %%
import torchvision.transforms as T
from PIL import Image, ImageDraw

def draw(images, lines, scores, thrh):
    for i, im in enumerate(images):
        draw = ImageDraw.Draw(im)

        scr = scores[i]
        line = lines[i][scr > thrh]
        scrs = scr[scr > thrh]

        for j, l in enumerate(line):
            draw.line(list(l), fill="red", width=5)
            draw.text(
                (l[0], l[1]),
                text=f"{round(scrs[j].item(), 2)}",
                fill="blue",
            )

    return images


transforms = T.Compose(
        [
            T.Resize((640, 640)),
            T.ToTensor(),
            T.Normalize(mean=[0.538, 0.494, 0.453], std=[0.257, 0.263, 0.273]),
        ]
    )

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)
model.eval()

img_file = '0004.jpg_012.png'
im_pil = Image.open(img_file).convert("RGB")

w, h = im_pil.size
orig_size = torch.tensor([[w, h]]).to(device)

im_data = transforms(im_pil).unsqueeze(0).to(device)

output = model(im_data, orig_size)
lines, scores = output

result_images = draw([im_pil], lines, scores, thrh=0.4)

# %%
result_images[0]
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>
